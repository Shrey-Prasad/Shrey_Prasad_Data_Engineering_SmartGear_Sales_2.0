# %% [markdown]
# # SmartGear Sales - EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('smartgear_sales.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df['revenue'] = df['quantity'] * df['price']
df.groupby('region')['revenue'].sum().plot(kind='bar')
plt.show()
